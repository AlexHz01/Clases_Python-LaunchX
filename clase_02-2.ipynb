# %%
name = "kike hernandez"

print(name.title())
# Out:
# Kike Hernandez

# %%
print(name.upper())
# mayuscula
# Out:
# KIKE HERNANDEZ

# %%
print(name.lower())
#minuscula
# Out:
# kike hernandez

# %%
print(name.islower())
print(name)
# Out:
# True
# kike hernandez

# %%
first_name = "kike"
last_name =  "                                     hernandez        "
print(first_name + " " + last_name)
# Out:
# kike                                      hernandez

# %%
#quitar espacios 
last_name = last_name.strip()
print(last_name)
# Out:
# hernandez

# %%
#quitar espacios 
last_name = "                                 kike"
last_name = last_name.lstrip()
print(last_name)
# Out:
# kike

# %%
# usando variables en cadenas 

nombre = "Riusey"
apellido ="Chable"
nombre_completo = f"{nombre} {apellido}"
print(nombre_completo)
# Out:
# Riusey Chable

# %% [markdown]
# ## lista

# %%
ingredientes = ["huevo", "arina", "leche" ]

# %%
## buscar el primero
ingredientes[0]
# Out:
# 'huevo'

# %%
ingredientes[-1]
# Out:
# 'leche'

# %%
##Agregar elemento

ingredientes.append("mantequilla")
print(ingredientes)
# Out:
# ['huevo', 'arina', 'leche', 'mantequilla']

# %%
#insertar ingrediente 

ingredientes.insert(2, "vainilla")
print(ingredientes)
# Out:
# ['huevo', 'arina', 'vainilla', 'leche', 'mantequilla']

# %%
ingredientes.insert(2, "vainilla")
print(ingredientes)
# Out:
# ['huevo', 'arina', 'vainilla', 'vainilla', 'leche', 'mantequilla']

# %%
## scar un elemnto de la lista
ingredientes.pop(3)
print(ingredientes)
# Out:
# ['huevo', 'arina', 'vainilla', 'leche', 'mantequilla']

# %%
## Remover un ingrediente de la lista 

ingredientes.remove("arina")
print(ingredientes)
# Out:
# ['huevo', 'vainilla', 'leche', 'mantequilla']

# %%
## ordenar de A-Z
 ingredientes.sort()
 print(ingredientes)
# Out:
# ['huevo', 'leche', 'mantequilla', 'vainilla']

# %%
## REverse 

ingredientes.reverse()
print(ingredientes)
# Out:
# ['vainilla', 'mantequilla', 'leche', 'huevo']

# %%
len(ingredientes)
# Out:
# 4

# %%
print(ingredientes[-1])
# Out:
# huevo

# %%
primeros_dos = ingredientes [:2]
print(primeros_dos)
# Out:
# ['vainilla', 'mantequilla']

# %%
## copiamos una lista

copy_list = ingredientes [:]
print(copy_list)
# Out:
# ['vainilla', 'mantequilla', 'leche', 'huevo']

# %%
## cupcake

el_cliente_quiere = [ "crema de chococalte", "chispas", "relleno de crema", "nueces"]

for extra in el_cliente_quiere:
    print(f"añadiendo ingredietes a la orden: {extra}" )

print("\n Tu cupcake esta listo")
# Out:
# añadiendo ingredietes a la orden: crema de chococalte
# añadiendo ingredietes a la orden: chispas
# añadiendo ingredietes a la orden: relleno de crema
# añadiendo ingredietes a la orden: nueces
#
#  Tu cupcake esta listo

# %%
## no hay ingredientes 

el_cliente_quiere = [ "crema de chococalte", "chispas", "relleno de crema", "nueces"]

for extra in el_cliente_quiere:
    if extra == "nueces":
        print("lo sentimos no hay nueces, puedes agregar almendras")
    else:
        print(f"añadiendo ingredientes a la orden: {extra}" )

print("\n tu cupck cake esta listo")
# Out:
# añadiendo ingredientes a la orden: crema de chococalte
# añadiendo ingredientes a la orden: chispas
# añadiendo ingredientes a la orden: relleno de crema
# lo sentimos no hay nueces, puedes agregar almendras
#
#  tu cupck cake esta listo

# %%
# como saver que ingredientes estan disponible

extra_disponible = ["perlas","canela"]

el_cliente_quiere = [ "crema de chococalte", "chispas", "relleno de crema", "nueces"]

for extra in el_cliente_quiere:
    if extra in el_cliente_quiere:
        print(f"Añadiendo {extra}.")
    else:
        print()
